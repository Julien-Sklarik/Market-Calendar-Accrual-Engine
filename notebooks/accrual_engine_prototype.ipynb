# %% [markdown]
# # Accrual engine prototype
#
# This notebook demonstrates the calendar and accrual functions with a couple of examples.
#
# Replace this file with your original research notebook if you prefer.
